# %% [markdown]
# # [作業目標]
#
# 1. [簡答題] 請問下列這三種方法有什麼不同？
#
# ```
# print(a.sum())
# print(np.sum(a))
# print(sum(a))
# ```
#
# 2. 請對一個 5x5 的隨機矩陣作正規化的操作。
#
# 3. 請建立一個長度等於 10 的正整數向量，並且將其中的最大值改成 -1。

# %% [markdown]
# # 作業

# %% [markdown]
# ### 1. [簡答題] 請問下列這三種方法有什麼不同？
#
# ```
# print(a.sum())
# print(np.sum(a))
# print(sum(a))
# ```

# %%
'''
sum為python 函式，np.sum()及a.sum()為numpy函式
'''
# Out:
# '\nYour Code\n'

# %% [markdown]
# ### 2. 請對一個 5x5 的隨機矩陣作正規化的操作。

# %%
# 記得先 Import 正確的套件

import numpy as np

# %%
A = np.random.random((5, 5))
A
A = (A - A.min())/(A.max()-A.min())
A
# Out:
# array([[0.26704676, 0.60609006, 0.16290301, 0.44841876, 0.5481317 ],
#        [0.12050146, 0.        , 0.46235469, 1.        , 0.07907507],
#        [0.13721301, 0.58175614, 0.90225463, 0.06416962, 0.97245081],
#        [0.22888905, 0.64249021, 0.76673283, 0.18545802, 0.99566826],
#        [0.59542393, 0.55451463, 0.61824305, 0.6749333 , 0.0272406 ]])

# %% [markdown]
# ### 3. 請建立一個長度等於 10 的正整數向量，並且將其中的最大值改成 -1。

# %%
A = np.random.random(10)
A[A.argmax()] = -1
print(A)
# Out:
# [ 0.34431475  0.51206146  0.25678644  0.00180095  0.12645674  0.67717753
#  -1.          0.50469358  0.50907051  0.59772322]
